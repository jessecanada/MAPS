# %% [markdown]
# <a href="https://colab.research.google.com/github/jessecanada/MAPS/blob/master/MAPS_4_phenotype_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MAPS Step 4 - phenotype classification with Azure
# ## This notebook will guide you through how to deploy your own Azure object detection model to perform phenotype classification.
# ### For help with creating an Azure deep learning model, follow this guide: https://docs.microsoft.com/en-us/azure/cognitive-services/custom-vision-service/get-started-build-detector

# %% [markdown]
# ## Set up Azure environtment

# %%
# !pip -q install azure-cognitiveservices-vision-customvision
from azure.cognitiveservices.vision.customvision.training import CustomVisionTrainingClient
from azure.cognitiveservices.vision.customvision.training.models import ImageFileCreateEntry, Region
from azure.cognitiveservices.vision.customvision.prediction import CustomVisionPredictionClient

# %%
from google.colab import files
import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt
import os
# %matplotlib inline

# %%
# gather the following info from your Azure Custom Vision project and input them here

ENDPOINT = "input endpoing"
training_key = "input training key"
prediction_key = "input prediction key"
prediction_resource_id = "input resource ID"
trainer = CustomVisionTrainingClient(training_key, endpoint=ENDPOINT)

publish_iteration_name = "input iteration name"

project = trainer.get_project(project_id='input project ID')

# %%
project.id # double check project ID to make sure it's correct

# %%
trainer = CustomVisionTrainingClient(training_key, endpoint=ENDPOINT)
predictor = CustomVisionPredictionClient(prediction_key, endpoint=ENDPOINT)

# %% [markdown]
# ## Get your files ready
#
# > ### It is recommanded that you upload your cell images onto Google Drive, then import it into this virtual machine session.
# > ### Alternatively, you can upload from your local drive to this session.

# %%
# mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# %%
# !unzip file_path -d /content/

# %%
# confirm how many cells are to be analyzed
# !ls unzipped_folder_path | wc -l

# %% [markdown]
# ## Azure classification predictions

# %% [markdown]
# ### Do a test prediction

# %%
# first image and first set of predictions

with open('input file path', "rb") as image: # r = read, b = binary (eg. images)
    results = predictor.classify_image(project.id, publish_iteration_name, image)

    # get the prediction results
    for prediction in results.predictions:
        print("\t" + prediction.tag_name + ": {0:.2f}%".format(prediction.probability * 100))
    
    print()
    
    probabilities = [prediction.probability*100 for prediction in results.predictions]
    col_names = [prediction.tag_name for prediction in results.predictions]

    df_test1 = pd.DataFrame([probabilities], columns = col_names)
    df_test1.insert(0, 'image_ID', 'test_img_1')

    print(df_test1)
# Out:
# 	non_nuclear: 99.95%
# 	diffused: 0.05%
# 	nuclear: 0.00%
#
#      image_ID  non_nuclear  diffused   nuclear
# 0  test_img_1     99.95431  0.045688  0.000012

# %% [markdown]
# ### Make batch predictions

# %%
wrk_dir = '/content/Y180H_singles_RGB_manually_filtered/'
temp_list = []

for entry in os.scandir(wrk_dir):
  if entry.name.endswith('.jpg'):
    image_ID = entry.name[:-4]
    print(f'image_ID: {image_ID}')

    # open an image and get back the prediction results
    with open(wrk_dir+entry.name, mode="rb") as image: #'r'-read, 'b'-binary (for images)
      results = predictor.classify_image(project.id, publish_iteration_name, image)
    
      # get the results
      tags = [prediction.tag_name for prediction in results.predictions]
      probabilities = [prediction.probability*100 for prediction in results.predictions]
      # make a dictionary of tag:prob pairs
      predictions_dict = dict(zip(tags, probabilities))
      # sort the tags in alphabetical order, append the corresponding prob of the sorted tags
      predictions_list = [predictions_dict[i] for i in sorted(predictions_dict)]
      # add image_ID to the beginning of the list
      predictions_list.insert(0, image_ID)
      # append the sorted list to a list as a compound list
      temp_list.append(predictions_list)
    
      for i in sorted(predictions_dict) : 
        print(f'{i}: {predictions_dict[i]}:.2f') 
      print()
# Out:
# image_ID: merged_191024160001_A02f100_2
# diffused: 1.06238875e-06:.2f
# non_nuclear: 100.0:.2f
# nuclear: 1.76529166e-31:.2f
#
# image_ID: merged_191024160002_A02f250_4
# diffused: 0.38223352699999996:.2f
# non_nuclear: 99.61777000000001:.2f
# nuclear: 1.41995936e-13:.2f
#
# image_ID: merged_191024160002_A02f249_5
# diffused: 99.9204338:.2f
# non_nuclear: 0.0119858538:.2f
# nuclear: 0.06758246450000001:.2f
#
# image_ID: merged_191024160002_A02f262_7
# diffused: 99.99997619999999:.2f
# non_nuclear: 2.20268831e-05:.2f
# nuclear: 1.00542645e-15:.2f
#
# image_ID: merged_191024160002_A02f294_12
# diffused: 0.0019529460000000001:.2f
# non_nuclear: 99.998045:.2f
# nuclear: 2.8986516299999996e-15:.2f
#
# image_ID: merged_191024160002_A02f275_2
# diffused: 100.0:.2f
# non_nuclear: 4.500061e-06:.2f
# nuclear: 2.62980924e-13:.2f
#
# image_ID: merged_191024160002_A02f289_0
# diffused: 0.00246070158:.2f
# non_nuclear: 99.9975443:.2f
# nuclear: 3.6422344100000003e-20:.2f
#
# image_ID: merged_191024160002_A02f262_0
# diffused: 1.77318616e-33:.2f
# non_nuclear: 100.0:.2f
# nuclear: 2.42108372e-30:.2f
#
# image_ID: merged_191024160002_A02f298_6
# diffused: 7.095198380000001e-05:.2f
# non_nuclear: 7.21356049:.2f
# nuclear: 92.78636999999999:.2f
#
# image_ID: merged_191024160002_A02f310_6
# diffused: 3.8162290000000003:.2f
# non_nuclear: 96.18377:.2f
# nuclear: 2.2029393e-11:.2f
#
# image_ID: merged_191024160001_A02f119_4
# diffused: 1.5990927699999999e-06:.2f
# non_nuclear: 99.73256:.2f
# nuclear: 0.267441641:.2f
#
# image_ID: merged_191024160002_A02f249_7
# diffused: 1.231053e-37:.2f
# non_nuclear: 100.0:.2f
# nuclear: 0.0:.2f
#
# image_ID: merged_191024160001_A02f116_4
# diffused: 20.4827338:.2f
# non_nuclear: 9.580612e-09:.2f
# nuclear: 79.51727:.2f
#
# image_ID: merged_191024160002_A02f284_5
# diffused: 0.335821:.2f
# non_nuclear: 99.60824000000001:.2f
# nuclear: 0.05593973:.2f
#
# image_ID: merged_191024160002_A02f250_7
# diffused: 5.16735241e-06:.2f
# non_nuclear: 100.0:.2f
# nuclear: 7.39757154e-21:.2f
#
# image_ID: merged_191024160002_A02f224_2
# diffused: 1.80370287e-17:.2f
# non_nuclear: 100.0:.2f
# nuclear: 6.68826536e-24:.2f
#
# image_ID: merged_191024160001_A02f116_8
# diffused: 9.287635629999999e-12:.2f
# non_nuclear: 100.0:.2f
# nuclear: 1.1100349200000001e-16:.2f
#
# image_ID: merged_191024160002_A02f297_7
# diffused: 0.0118764758:.2f
# non_nuclear: 99.9881268:.2f
# nuclear: 1.52130166e-06:.2f
#
# image_ID: merged_191024160002_A02f262_10
# diffused: 4.82751554e-12:.2f
# non_nuclear: 99.91479:.2f
# nuclear: 0.08521167:.2f
#
# image_ID: merged_191024160002_A02f255_1
# diffused: 1.09827631e-10:.2f
# non_nuclear: 100.0:.2f
# nuclear: 1.48936215e-24:.2f
#
# image_ID: merged_191024160002_A02f224_1
# diffused: 7.00544043e-18:.2f
# non_nuclear: 100.0:.2f
# nuclear: 1.98408087e-32:.2f
#
# image_ID: merged_191024160002_A02f226_5
# diffused: 0.0698993448:.2f
# non_nuclear: 99.90415:.2f
# nuclear: 0.0259512977:.2f
#
# image_ID: merged_191024160002_A02f258_1
# diffused: 5.775646e-14:.2f
# non_nuclear: 2.96465666e-21:.2f
# nuclear: 100.0:.2f
#
# image_ID: merged_191024160002_A02f294_7
# diffused: 6.04248555e-05:.2f
# non_nuclear: 99.99994:.2f
# nuclear: 7.582232e-32:.2f
#
# image_ID: merged_191024160002_A02f230_2
# diffused: 9.098544e-21:.2f
# non_nuclear: 6.57513358e-17:.2f
# nuclear: 100.0:.2f
#
# image_ID: merged_191024160002_A02f297_3
# diffused: 99.98324:.2f
# non_nuclear: 4.759151e-15:.2f
# nuclear: 0.0167616134:.2f
#
# image_ID: merged_191024160002_A02f294_1
# diffused: 99.99602:.2f
# non_nuclear: 1.70991427e-05:.2f
# nuclear: 0.00396275464:.2f
#
# image_ID: merged_191024160002_A02f230_7
# diffused: 2.18510526e-24:.2f
# non_nuclear: 3.90291358e-16:.2f
# nuclear: 100.0:.2f
#
# image_ID: merged_191024160001_A02f100_9
# diffused: 0.008312773570000001:.2f
# non_nuclear: 1.689755e-19:.2f
# nuclear: 99.99169:.2f
#
# image_ID: merged_191024160002_A02f296_0
# diffused: 100.0:.2f
# non_nuclear: 1.2428226100000002e-19:.2f
# nuclear: 1.0491934099999999e-16:.2f
#
# image_ID: merged_191024160001_A02f100_1
# diffused: 0.24954030000000002:.2f
# non_nuclear: 99.75046520000001:.2f
# nuclear: 2.86113633e-08:.2f
#
# image_ID: merged_191024160002_A02f297_5
# diffused: 1.18735514e-05:.2f
# non_nuclear: 99.99999000000001:.2f
# nuclear: 6.20824546e-20:.2f
#
# image_ID: merged_191024160002_A02f294_11
# diffused: 5.669275e-10:.2f
# non_nuclear: 100.0:.2f
# nuclear: 8.919946e-20:.2f
#
# image_ID: merged_191024160002_A02f255_0
# diffused: 0.000444623629:.2f
# non_nuclear: 99.99956:.2f
# nuclear: 2.0501979999999998e-14:.2f
#
# image_ID: merged_191024160002_A02f218_1
# diffused: 6.363568e-14:.2f
# non_nuclear: 100.0:.2f
# nuclear: 9.097308e-33:.2f
#
# image_ID: merged_191024160002_A02f284_6
# diffused: 0.41291089999999997:.2f
# non_nuclear: 99.58682:.2f
# nuclear: 0.000267491214:.2f
#
# image_ID: merged_191024160002_A02f294_8
# diffused: 100.0:.2f
# non_nuclear: 1.0898252100000001e-06:.2f
# nuclear: 6.406294e-20:.2f
#
# image_ID: merged_191024160002_A02f294_3
# diffused: 100.0:.2f
# non_nuclear: 4.4062660000000005e-07:.2f
# nuclear: 7.56898e-15:.2f
#
# image_ID: merged_191024160002_A02f224_0
# diffused: 15.170919999999999:.2f
# non_nuclear: 84.7982943:.2f
# nuclear: 0.030786229999999998:.2f
#
# image_ID: merged_191024160001_A02f116_0
# diffused: 99.9997854:.2f
# non_nuclear: 0.00021714724899999998:.2f
# nuclear: 7.404977e-07:.2f
#
# image_ID: merged_191024160002_A02f262_1
# diffused: 0.00272567177:.2f
# non_nuclear: 99.9972761:.2f
# nuclear: 1.69388567e-16:.2f
#
# image_ID: merged_191024160002_A02f249_6
# diffused: 2.341569e-23:.2f
# non_nuclear: 100.0:.2f
# nuclear: 7.315866e-17:.2f
#
# image_ID: merged_191024160002_A02f226_3
# diffused: 6.9068674399999995e-09:.2f
# non_nuclear: 100.0:.2f
# nuclear: 3.4500301699999997e-23:.2f
#
# image_ID: merged_191024160002_A02f249_8
# diffused: 1.27665763e-17:.2f
# non_nuclear: 100.0:.2f
# nuclear: 2.00011664e-23:.2f
#
# image_ID: merged_191024160002_A02f250_6
# diffused: 9.065762e-15:.2f
# non_nuclear: 100.0:.2f
# nuclear: 1.4495117200000002e-29:.2f
#
# image_ID: merged_191024160001_A02f100_8
# diffused: 1.26270166e-05:.2f
# non_nuclear: 99.99999000000001:.2f
# nuclear: 4.0944993e-14:.2f
#
# image_ID: merged_191024160002_A02f222_0
# diffused: 100.0:.2f
# non_nuclear: 5.22795349e-10:.2f
# nuclear: 6.825784e-14:.2f
#
# image_ID: merged_191024160001_A02f100_6
# diffused: 0.000155056466:.2f
# non_nuclear: 33.510974:.2f
# nuclear: 66.48887:.2f
#
# image_ID: merged_191024160002_A02f250_8
# diffused: 3.83415921e-17:.2f
# non_nuclear: 100.0:.2f
# nuclear: 1.64255041e-13:.2f
#
# image_ID: merged_191024160002_A02f275_3
# diffused: 99.99314:.2f
# non_nuclear: 0.00686162748:.2f
# nuclear: 3.963386000000001e-12:.2f
#
# image_ID: merged_191024160002_A02f230_6
# diffused: 2.1737347299999998e-29:.2f
# non_nuclear: 4.591688e-25:.2f
# nuclear: 100.0:.2f
#
# image_ID: merged_191024160002_A02f249_3
# diffused: 3.31956728e-10:.2f
# non_nuclear: 1.60738531e-14:.2f
# nuclear: 100.0:.2f
#
# image_ID: merged_191024160002_A02f294_2
# diffused: 100.0:.2f
# non_nuclear: 4.73457018e-18:.2f
# nuclear: 2.6783337000000002e-36:.2f
#
# image_ID: merged_191024160002_A02f294_6
# diffused: 100.0:.2f
# non_nuclear: 1.830637e-09:.2f
# nuclear: 4.5244836999999994e-26:.2f
#
# image_ID: merged_191024160002_A02f275_1
# diffused: 100.0:.2f
# non_nuclear: 7.88781e-14:.2f
# nuclear: 3.5647448e-11:.2f
#
# image_ID: merged_191024160002_A02f250_5
# diffused: 12.1201515:.2f
# non_nuclear: 87.87985:.2f
# nuclear: 1.3520035e-11:.2f
#
# image_ID: merged_191024160002_A02f226_1
# diffused: 5.2478079999999996e-20:.2f
# non_nuclear: 100.0:.2f
# nuclear: 1.632513e-40:.2f
#
# image_ID: merged_191024160001_A02f120_6
# diffused: 1.29260975e-15:.2f
# non_nuclear: 100.0:.2f
# nuclear: 1.98195963e-20:.2f
#
# image_ID: merged_191024160002_A02f230_5
# diffused: 9.704681999999999e-08:.2f
# non_nuclear: 100.0:.2f
# nuclear: 1.04665432e-06:.2f
#
# image_ID: merged_191024160002_A02f262_8
# diffused: 99.99999000000001:.2f
# non_nuclear: 1.67272168e-09:.2f
# nuclear: 9.460897e-06:.2f
#
# image_ID: merged_191024160001_A02f120_4
# diffused: 3.125454e-10:.2f
# non_nuclear: 0.6946969:.2f
# nuclear: 99.3053:.2f
#
# image_ID: merged_191024160002_A02f289_1
# diffused: 98.7634361:.2f
# non_nuclear: 0.23665209999999998:.2f
# nuclear: 0.9999139:.2f
#
# image_ID: merged_191024160002_A02f249_2
# diffused: 0.06071501:.2f
# non_nuclear: 72.46258:.2f
# nuclear: 27.4767071:.2f
#
# image_ID: merged_191024160001_A02f80_3
# diffused: 100.0:.2f
# non_nuclear: 3.339452e-13:.2f
# nuclear: 8.88296658e-09:.2f
#
# image_ID: merged_191024160002_A02f232_5
# diffused: 99.1321:.2f
# non_nuclear: 0.8678972:.2f
# nuclear: 1.78187083e-19:.2f
#
# image_ID: merged_191024160002_A02f226_4
# diffused: 0.0787870551:.2f
# non_nuclear: 99.9212146:.2f
# nuclear: 1.65862431e-17:.2f
#
# image_ID: merged_191024160002_A02f310_8
# diffused: 100.0:.2f
# non_nuclear: 1.29889255e-07:.2f
# nuclear: 3.18889143e-10:.2f
#
# image_ID: merged_191024160002_A02f291_2
# diffused: 1.92593811e-12:.2f
# non_nuclear: 100.0:.2f
# nuclear: 2.69078936e-34:.2f
#
# image_ID: merged_191024160002_A02f310_9
# diffused: 5.572329e-10:.2f
# non_nuclear: 5.024272490000001e-13:.2f
# nuclear: 100.0:.2f
#
# image_ID: merged_191024160002_A02f224_3
# diffused: 2.32892958e-06:.2f
# non_nuclear: 99.99996420000001:.2f
# nuclear: 3.308273e-05:.2f
#
# image_ID: merged_191024160002_A02f224_5
# diffused: 99.99996420000001:.2f
# non_nuclear: 1.32534738e-10:.2f
# nuclear: 3.967948e-05:.2f
#
# image_ID: merged_191024160002_A02f291_1
# diffused: 2.0155868700000002e-32:.2f
# non_nuclear: 100.0:.2f
# nuclear: 0.0:.2f
#
# image_ID: merged_191024160002_A02f255_2
# diffused: 2.356346e-07:.2f
# non_nuclear: 100.0:.2f
# nuclear: 6.86205237e-20:.2f
#
# image_ID: merged_191024160002_A02f249_4
# diffused: 7.871987e-17:.2f
# non_nuclear: 100.0:.2f
# nuclear: 7.52128828e-11:.2f
#
# image_ID: merged_191024160002_A02f298_3
# diffused: 0.009948245999999999:.2f
# non_nuclear: 99.98753:.2f
# nuclear: 0.00252254613:.2f
#
# image_ID: merged_191024160001_A02f120_5
# diffused: 0.9969037000000001:.2f
# non_nuclear: 99.0031:.2f
# nuclear: 1.540074e-19:.2f
#
# image_ID: merged_191024160002_A02f284_2
# diffused: 12.3006053:.2f
# non_nuclear: 5.73753e-05:.2f
# nuclear: 87.6993358:.2f
#
# image_ID: merged_191024160002_A02f284_1
# diffused: 3.6846876699999995e-17:.2f
# non_nuclear: 100.0:.2f
# nuclear: 3.5551002499999996e-20:.2f
#
# image_ID: merged_191024160002_A02f232_6
# diffused: 6.051488e-06:.2f
# non_nuclear: 99.999994:.2f
# nuclear: 6.33996268e-23:.2f
#
# image_ID: merged_191024160001_A02f120_8
# diffused: 8.358176000000001e-23:.2f
# non_nuclear: 100.0:.2f
# nuclear: 7.97318367e-36:.2f
#
# image_ID: merged_191024160001_A02f116_6
# diffused: 1.10635737e-08:.2f
# non_nuclear: 100.0:.2f
# nuclear: 1.11023394e-31:.2f
#
# image_ID: merged_191024160002_A02f288_1
# diffused: 4.59059068e-15:.2f
# non_nuclear: 100.0:.2f
# nuclear: 3.203691e-34:.2f
#
# image_ID: merged_191024160002_A02f297_1
# diffused: 3.6494863400000004e-35:.2f
# non_nuclear: 100.0:.2f
# nuclear: 0.0:.2f
#
# image_ID: merged_191024160002_A02f288_3
# diffused: 9.927172e-15:.2f
# non_nuclear: 100.0:.2f
# nuclear: 3.9919126499999997e-19:.2f
#
# image_ID: merged_191024160002_A02f310_5
# diffused: 99.5918453:.2f
# non_nuclear: 3.99633e-11:.2f
# nuclear: 0.40815244400000006:.2f
#
# image_ID: merged_191024160001_A02f116_5
# diffused: 0.0006695264:.2f
# non_nuclear: 2.7145614300000002e-15:.2f
# nuclear: 99.99933:.2f
#
# image_ID: merged_191024160001_A02f120_2
# diffused: 100.0:.2f
# non_nuclear: 1.62102786e-10:.2f
# nuclear: 3.46056076e-16:.2f
#
# image_ID: merged_191024160001_A02f120_7
# diffused: 0.0368143839:.2f
# non_nuclear: 99.96319:.2f
# nuclear: 8.900864e-19:.2f
#
# image_ID: merged_191024160001_A02f116_11
# diffused: 8.89356e-06:.2f
# non_nuclear: 0.0114297494:.2f
# nuclear: 99.98856:.2f
#
# image_ID: merged_191024160002_A02f288_2
# diffused: 1.0602002:.2f
# non_nuclear: 0.6247952579999999:.2f
# nuclear: 98.3150065:.2f
#
# image_ID: merged_191024160001_A02f99_3
# diffused: 0.000319448236:.2f
# non_nuclear: 99.99968:.2f
# nuclear: 1.00936559e-09:.2f
#
# image_ID: merged_191024160002_A02f298_4
# diffused: 9.58094746:.2f
# non_nuclear: 90.419054:.2f
# nuclear: 3.78870841e-26:.2f
#
# image_ID: merged_191024160002_A02f262_11
# diffused: 3.7420925e-06:.2f
# non_nuclear: 99.9998331:.2f
# nuclear: 0.000155088924:.2f
#
# image_ID: merged_191024160002_A02f294_5
# diffused: 0.00159525553:.2f
# non_nuclear: 99.9984:.2f
# nuclear: 1.1160577499999999e-26:.2f
#
# image_ID: merged_191024160001_A02f80_2
# diffused: 54.2903543:.2f
# non_nuclear: 45.70965:.2f
# nuclear: 2.57738213e-21:.2f
#
# image_ID: merged_191024160001_A02f120_3
# diffused: 100.0:.2f
# non_nuclear: 4.611355e-07:.2f
# nuclear: 4.3071045e-21:.2f
#
# image_ID: merged_191024160002_A02f249_1
# diffused: 100.0:.2f
# non_nuclear: 4.114983e-13:.2f
# nuclear: 1.20036576e-10:.2f
#
# image_ID: merged_191024160002_A02f291_3
# diffused: 0.5941812000000001:.2f
# non_nuclear: 1.28343058e-07:.2f
# nuclear: 99.4058132:.2f
#
# image_ID: merged_191024160002_A02f255_3
# diffused: 1.4469708000000001e-21:.2f
# non_nuclear: 100.0:.2f
# nuclear: 1.665864e-39:.2f
#
# image_ID: merged_191024160002_A02f275_0
# diffused: 100.0:.2f
# non_nuclear: 3.9002909999999997e-10:.2f
# nuclear: 5.17161176e-06:.2f
#
# image_ID: merged_191024160002_A02f262_5
# diffused: 99.99999000000001:.2f
# non_nuclear: 1.5705579100000003e-06:.2f
# nuclear: 1.25059287e-05:.2f
#
# image_ID: merged_191024160002_A02f297_2
# diffused: 0.6642607509999999:.2f
# non_nuclear: 99.33574:.2f
# nuclear: 2.48934449e-09:.2f
#
# image_ID: merged_191024160001_A02f119_2
# diffused: 2.7463394099999997e-21:.2f
# non_nuclear: 5.222191e-26:.2f
# nuclear: 100.0:.2f
#
# image_ID: merged_191024160002_A02f232_3
# diffused: 0.00031484950000000003:.2f
# non_nuclear: 99.99969:.2f
# nuclear: 1.5018516200000002e-06:.2f
#
# image_ID: merged_191024160002_A02f224_4
# diffused: 2.14124171e-05:.2f
# non_nuclear: 99.99997619999999:.2f
# nuclear: 4.02800514e-11:.2f
#
# image_ID: merged_191024160002_A02f297_4
# diffused: 2.21589943e-20:.2f
# non_nuclear: 100.0:.2f
# nuclear: 5.1291208e-19:.2f
#
# image_ID: merged_191024160002_A02f297_6
# diffused: 2.23506635e-07:.2f
# non_nuclear: 100.0:.2f
# nuclear: 1.5181645399999998e-23:.2f
#
# image_ID: merged_191024160001_A02f116_9
# diffused: 4.49645945e-09:.2f
# non_nuclear: 100.0:.2f
# nuclear: 5.64288535e-22:.2f
#
# image_ID: merged_191024160002_A02f262_6
# diffused: 1.18378232e-24:.2f
# non_nuclear: 100.0:.2f
# nuclear: 0.0:.2f
#
# image_ID: merged_191024160002_A02f255_5
# diffused: 1.61045251e-16:.2f
# non_nuclear: 100.0:.2f
# nuclear: 3.48201355e-23:.2f
#
# image_ID: merged_191024160001_A02f100_5
# diffused: 11.745137:.2f
# non_nuclear: 88.25292:.2f
# nuclear: 0.0019456641899999998:.2f
#
# image_ID: merged_191024160002_A02f294_9
# diffused: 100.0:.2f
# non_nuclear: 7.081842e-07:.2f
# nuclear: 3.40281447e-07:.2f
#
# image_ID: merged_191024160002_A02f250_1
# diffused: 3.24058143e-24:.2f
# non_nuclear: 3.5440937e-19:.2f
# nuclear: 100.0:.2f
#
# image_ID: merged_191024160002_A02f262_2
# diffused: 100.0:.2f
# non_nuclear: 1.9862282e-09:.2f
# nuclear: 8.904296e-15:.2f
#
# image_ID: merged_191024160002_A02f262_4
# diffused: 80.84171:.2f
# non_nuclear: 19.1463575:.2f
# nuclear: 0.0119379241:.2f
#
# image_ID: merged_191024160002_A02f226_2
# diffused: 1.49611416e-11:.2f
# non_nuclear: 100.0:.2f
# nuclear: 4.09780637e-32:.2f
#
# image_ID: merged_191024160002_A02f232_4
# diffused: 1.1825584999999998e-10:.2f
# non_nuclear: 2.10303927e-09:.2f
# nuclear: 100.0:.2f
#
# image_ID: merged_191024160001_A02f99_0
# diffused: 6.41620437e-11:.2f
# non_nuclear: 3.633895e-15:.2f
# nuclear: 100.0:.2f
#
# image_ID: merged_191024160002_A02f232_1
# diffused: 2.11615e-15:.2f
# non_nuclear: 1.4028841e-23:.2f
# nuclear: 100.0:.2f
#
# image_ID: merged_191024160002_A02f284_3
# diffused: 0.0022584567:.2f
# non_nuclear: 99.9977469:.2f
# nuclear: 2.34049035e-22:.2f
#
# image_ID: merged_191024160001_A02f116_3
# diffused: 99.99823570000001:.2f
# non_nuclear: 0.00176834874:.2f
# nuclear: 6.905012510000001e-30:.2f
#
# image_ID: merged_191024160002_A02f232_0
# diffused: 4.005648e-10:.2f
# non_nuclear: 3.883664:.2f
# nuclear: 96.1163342:.2f
#
# image_ID: merged_191024160002_A02f258_0
# diffused: 99.8784:.2f
# non_nuclear: 0.08772044:.2f
# nuclear: 0.03387985:.2f
#
# image_ID: merged_191024160002_A02f222_9
# diffused: 0.000620477749:.2f
# non_nuclear: 99.99938:.2f
# nuclear: 2.533797e-14:.2f
#
# image_ID: merged_191024160001_A02f100_4
# diffused: 2.397196e-06:.2f
# non_nuclear: 100.0:.2f
# nuclear: 2.04832667e-18:.2f
#
# image_ID: merged_191024160001_A02f80_1
# diffused: 99.9967158:.2f
# non_nuclear: 0.00018751366:.2f
# nuclear: 0.0030983446799999997:.2f
#
# image_ID: merged_191024160001_A02f116_2
# diffused: 0.00010334881599999999:.2f
# non_nuclear: 99.9999:.2f
# nuclear: 2.185645e-24:.2f
#
# image_ID: merged_191024160001_A02f119_3
# diffused: 0.0002815582:.2f
# non_nuclear: 95.07989:.2f
# nuclear: 4.9198260000000005:.2f
#
# image_ID: merged_191024160002_A02f275_4
# diffused: 0.0559287262:.2f
# non_nuclear: 99.94407:.2f
# nuclear: 6.333147e-18:.2f
#
# image_ID: merged_191024160002_A02f294_10
# diffused: 10.5220914:.2f
# non_nuclear: 89.47791459999999:.2f
# nuclear: 7.292674999999999e-10:.2f
#
# image_ID: merged_191024160002_A02f298_0
# diffused: 1.80571432e-12:.2f
# non_nuclear: 100.0:.2f
# nuclear: 1.006879e-27:.2f
#
# image_ID: merged_191024160001_A02f100_3
# diffused: 8.956981e-19:.2f
# non_nuclear: 100.0:.2f
# nuclear: 3.653746e-39:.2f
#
# image_ID: merged_191024160002_A02f222_2
# diffused: 99.93290999999999:.2f
# non_nuclear: 0.06709507:.2f
# nuclear: 6.845029e-14:.2f
#
# image_ID: merged_191024160002_A02f284_0
# diffused: 82.05015660000001:.2f
# non_nuclear: 0.000166155257:.2f
# nuclear: 17.949675000000003:.2f
#
# image_ID: merged_191024160002_A02f262_3
# diffused: 0.004649723:.2f
# non_nuclear: 99.99535:.2f
# nuclear: 7.514831e-22:.2f
#
# image_ID: merged_191024160002_A02f294_0
# diffused: 1.7203395799999999e-22:.2f
# non_nuclear: 100.0:.2f
# nuclear: 9.809089e-43:.2f
#
# image_ID: merged_191024160002_A02f232_2
# diffused: 8.828091999999999e-16:.2f
# non_nuclear: 2.24469483e-23:.2f
# nuclear: 100.0:.2f
#
# image_ID: merged_191024160002_A02f222_4
# diffused: 1.09056882e-15:.2f
# non_nuclear: 100.0:.2f
# nuclear: 1.401298e-43:.2f
#
# image_ID: merged_191024160002_A02f291_0
# diffused: 5.739462670000001e-25:.2f
# non_nuclear: 100.0:.2f
# nuclear: 0.0:.2f
#
# image_ID: merged_191024160002_A02f298_2
# diffused: 9.082268e-05:.2f
# non_nuclear: 99.99991:.2f
# nuclear: 1.17393026e-21:.2f
#
# image_ID: merged_191024160001_A02f80_0
# diffused: 98.9968061:.2f
# non_nuclear: 1.00318994:.2f
# nuclear: 3.8592992400000003e-22:.2f
#
# image_ID: merged_191024160002_A02f294_4
# diffused: 1.80961474e-11:.2f
# non_nuclear: 100.0:.2f
# nuclear: 1.0881018700000001e-35:.2f
#
# image_ID: merged_191024160002_A02f230_1
# diffused: 0.0:.2f
# non_nuclear: 100.0:.2f
# nuclear: 0.0:.2f
#
# image_ID: merged_191024160002_A02f230_3
# diffused: 3.3526870000000004e-05:.2f
# non_nuclear: 3.9378375e-05:.2f
# nuclear: 99.99993:.2f
#
# image_ID: merged_191024160001_A02f119_0
# diffused: 3.25326188e-07:.2f
# non_nuclear: 100.0:.2f
# nuclear: 3.9401069999999996e-21:.2f
#
# image_ID: merged_191024160002_A02f288_0
# diffused: 4.60495855e-06:.2f
# non_nuclear: 100.0:.2f
# nuclear: 3.119488e-20:.2f
#
# image_ID: merged_191024160002_A02f222_8
# diffused: 4.830077e-15:.2f
# non_nuclear: 100.0:.2f
# nuclear: 1.8749370000000003e-40:.2f
#
# image_ID: merged_191024160002_A02f222_3
# diffused: 100.0:.2f
# non_nuclear: 3.73779133e-09:.2f
# nuclear: 2.15786937e-09:.2f
#
# image_ID: merged_191024160002_A02f298_1
# diffused: 8.35244035e-15:.2f
# non_nuclear: 100.0:.2f
# nuclear: 2.296012e-19:.2f
#
# image_ID: merged_191024160002_A02f222_7
# diffused: 0.00010683180000000001:.2f
# non_nuclear: 99.99989000000001:.2f
# nuclear: 1.20325828e-16:.2f
#
# image_ID: merged_191024160001_A02f116_1
# diffused: 93.92405000000001:.2f
# non_nuclear: 6.04416355:.2f
# nuclear: 0.031789034300000005:.2f
#
# image_ID: merged_191024160002_A02f262_9
# diffused: 2.41365547e-19:.2f
# non_nuclear: 100.0:.2f
# nuclear: 6.358642e-14:.2f
#
# image_ID: merged_191024160002_A02f226_0
# diffused: 99.9986768:.2f
# non_nuclear: 0.00132181585:.2f
# nuclear: 1.06654e-15:.2f
#
# image_ID: merged_191024160001_A02f119_1
# diffused: 1.18892e-05:.2f
# non_nuclear: 99.99999000000001:.2f
# nuclear: 2.33122783e-06:.2f
#
# image_ID: merged_191024160002_A02f250_3
# diffused: 2.8928124599999997e-05:.2f
# non_nuclear: 99.99997619999999:.2f
# nuclear: 1.025506e-17:.2f
#
# image_ID: merged_191024160002_A02f255_4
# diffused: 3.060455e-15:.2f
# non_nuclear: 100.0:.2f
# nuclear: 1.67249807e-32:.2f

# %%
# Print out a few lines to see the predicted probabilities

col_names = [i for i in sorted(predictions_dict)]
col_names.insert(0, 'image_ID')
df_predict = pd.DataFrame(temp_list, columns = col_names)
df_predict.head(10)
# Out:
#                          image_ID      diffused  non_nuclear       nuclear
# 0   merged_191024160001_A02f100_2  1.062389e-06   100.000000  1.765292e-31
# 1   merged_191024160002_A02f250_4  3.822335e-01    99.617770  1.419959e-13
# 2   merged_191024160002_A02f249_5  9.992043e+01     0.011986  6.758246e-02
# 3   merged_191024160002_A02f262_7  9.999998e+01     0.000022  1.005426e-15
# 4  merged_191024160002_A02f294_12  1.952946e-03    99.998045  2.898652e-15
# 5   merged_191024160002_A02f275_2  1.000000e+02     0.000005  2.629809e-13
# 6   merged_191024160002_A02f289_0  2.460702e-03    99.997544  3.642234e-20
# 7   merged_191024160002_A02f262_0  1.773186e-33   100.000000  2.421084e-30
# 8   merged_191024160002_A02f298_6  7.095198e-05     7.213560  9.278637e+01
# 9   merged_191024160002_A02f310_6  3.816229e+00    96.183770  2.202939e-11

# %%
len(df_predict) # does it match the number of images in the folder?
# Out:
# 156

# %%
# save the dataframe to a csv file
df_predict.to_csv('your_file_name.csv', index=False)
